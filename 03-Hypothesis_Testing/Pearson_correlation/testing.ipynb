# %% [markdown]
# # import all libraries

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# # important function

# %%
from function.pearson_function import numerical_vs_numerical

# %% [markdown]
# # load data

# %%
df = pd.read_csv('../../00-dataSource/dataSourceV2/clean_data_v1.csv')
df.head()

# %% [markdown]
# ## hyothesis between Age & stress level

# %%
ttest_results = pd.DataFrame([
    numerical_vs_numerical(df, 'Age', 'Stress_Level(1-10)'),
])

ttest_results

# %% [markdown]
# The results show a very weak and statistically non-significant relationship between age and stress level (r = 0.0165, p > 0.05).
#
# This indicates that age does not have a meaningful impact on stress level in this dataset, and therefore may not be an important factor for prediction.

# %% [markdown]
# ## hyothesis between Daily_Screen_Time(hrs) & stress level

# %%
ttest_results = pd.DataFrame([
    numerical_vs_numerical(df, 'Daily_Screen_Time(hrs)', 'Stress_Level(1-10)'),
])

ttest_results

# %% [markdown]
# ## hyothesis between Sleep_Quality(1-10) & stress level

# %%
ttest_results = pd.DataFrame([
    numerical_vs_numerical(df, 'Sleep_Quality(1-10)', 'Stress_Level(1-10)'),
])

ttest_results

# %% [markdown]
# ## hyothesis between Days_Without_Social_Media & stress level

# %%
ttest_results = pd.DataFrame([
    numerical_vs_numerical(df, 'Days_Without_Social_Media', 'Stress_Level(1-10)'),
])

ttest_results
# Out:
#                   Test                                        Variables  \
# 0  Pearson Correlation  Days_Without_Social_Media vs Stress_Level(1-10)
#
#    Correlation (r)   p-value        Relationship           Decision  \
# 0           -0.008  0.858906  very weak negative  Fail to reject H0
#
#                                           Conclusion
# 0  The relationship between Days_Without_Social_M...
