# %% [markdown]
# Based on Hypothesis testing, we can see that gender feature have no effect (relationship) to target feature both stress level and produuctivity score. therefore, we dont need this feature anymore.

# %%
import pandas as pd

# load dataset
df = pd.read_csv("../../00-dataSource/clean_data_v1.csv")

# drop gender feature
df = df.drop(columns=['gender', 'age', 'study_mins'])

# Save cleaned dataset
df.to_csv("../../00-dataSource/clean_data_v2.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!
